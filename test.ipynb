# %%
import numpy as np
import pickle
import torch
import tkinter as tk
from cpp import generate_gif_from_path
from tkinter import filedialog
from docopt import docopt
from model import ActorCriticModel
from utils import create_env
import time
from datetime import datetime


def init_transformer_memory(trxl_conf, max_episode_steps, device):
    """Returns initial tensors for the episodic memory of the transformer.

    Arguments:
        trxl_conf {dict} -- Transformer configuration dictionary
        max_episode_steps {int} -- Maximum number of steps per episode
        device {torch.device} -- Target device for the tensors

    Returns:
        memory {torch.Tensor}, memory_mask {torch.Tensor}, memory_indices {torch.Tensor} -- Initial episodic memory, episodic memory mask, and sliding memory window indices
    """
    # Episodic memory mask used in attention
    memory_mask = torch.tril(torch.ones((trxl_conf["memory_length"], trxl_conf["memory_length"])), diagonal=-1)
    # Episdic memory tensor
    memory = torch.zeros((1, max_episode_steps, trxl_conf["num_blocks"], trxl_conf["embed_dim"])).to(device)
    # Setup sliding memory window indices
    repetitions = torch.repeat_interleave(torch.arange(0, trxl_conf["memory_length"]).unsqueeze(0), trxl_conf["memory_length"] - 1, dim = 0).long()
    memory_indices = torch.stack([torch.arange(i, i + trxl_conf["memory_length"]) for i in range(max_episode_steps - trxl_conf["memory_length"] + 1)]).long()
    memory_indices = torch.cat((repetitions, memory_indices))
    return memory, memory_mask, memory_indices
def load_model_path(default = False):
    root = tk.Tk()
    if default:
        return f"models/20240420-232428/2.391.nn "
    else:
        #default folder is model
        file_path = filedialog.askopenfilename(initialdir = "models")
        root.destroy()
        return file_path

def main(model,times):
    # Command line arguments via docopt
    _USAGE = """
    Usage:
        enjoy.py [options]
        enjoy.py --help
    
    Options:
        --model=<path>              Specifies the path to the trained model [default: ./models/run.nn].
    """
    # options = docopt(_USAGE)
    # model_path = options["--model"]
    # model_path = load_model_path()   
    # Set inference device and default tensor type
    device = torch.device("cpu")
    torch.set_default_tensor_type("torch.FloatTensor")

    # Load model and config
    state_dict, config = pickle.load(open(model_path, "rb"))

    # Instantiate environment
    env = create_env(config["environment"], render=True)

    # Initialize model and load its parameters
    model = ActorCriticModel(config, env.observation_space, (env.action_space.n,), env.max_episode_steps)
    model.load_state_dict(state_dict)
    model.to(device)
    model.eval()
    
    # Run and render episode
    done = False
    episode_rewards = []
    memory, memory_mask, memory_indices = init_transformer_memory(config["transformer"], env.max_episode_steps, device)
    memory_length = config["transformer"]["memory_length"]
    t = 0
    obs = env.reset()
    # G = env.create_networkx_graph()
    # NUM_NODES = env.num_nodes
    # Side = int(NUM_NODES**0.5)
    # pos = {i: (i % Side, Side - 1 - i // Side) for i in range(NUM_NODES)}
    # env.plot_graph(G,  pos, "test2.png")
    start_time = time.time()
    while not done:
        # Prepare observation and memory
        obs = torch.tensor(np.expand_dims(obs, 0), dtype=torch.float32, device=device)
        in_memory = memory[0, memory_indices[t].unsqueeze(0)]
        t_ = max(0, min(t, memory_length - 1))
        mask = memory_mask[t_].unsqueeze(0)
        indices = memory_indices[t].unsqueeze(0)
        # Render environment
        env.render()
        # Forward model
        policy, value, new_memory = model(obs, in_memory, mask, indices) #in_memory ([1, 64, 3, 512]) #indices 64
        # print(in_memory[0][0][0])#
        memory[:, t] = new_memory
        # Sample action
        action = []
        for action_branch in policy:
            action.append(action_branch.probs.argmax().item())
        # Step environemnt
        # print("next step is to go to ",int(action[0]))
        obs, reward, done, info = env.step(action)
        episode_rewards.append(reward)
        t += 1
    
    # after done, render last state
    env.render()
    end_time = time.time()
    elapsed_time = end_time - start_time
    print("Result is ",env.ok)
    # print(f"函數執行耗時：{elapsed_time} 秒")   
    print("Episode distance: " + str(info["distance"]))
    print("Episode length: " + str(info["length"]))
    print("Episode reward: " + str(info["reward"]))
    euler_path = env.path
    euler_path = [(str(euler_path[i]), str(euler_path[i + 1])) for i in range(len(euler_path) - 1)]
    repeat_path = euler_path
    # if env.ok == 0:
    generate_gif_from_path(env.create_networkx_graph() , env.get_pos(), euler_path, repeat_path, 1, int(info["distance"]))

    
    env.close()
    return env.ok, info

if __name__ == "__main__":
    model_path = load_model_path() 
    total_reward = 0
    total_length = 0
    done_length = 0
    total_dinstance = 0
    Test_times = 100
    done = 0
    for i in range(Test_times):
        print("Test_times",i)
        test, info = main(model_path,i)
        done = test + done
        total_reward += info["reward"]
        total_length += info["length"]
        total_dinstance += info["distance"]
        if test == 1:
            done_length += info["length"]
        print("Succesful: ", done/(i+1)*100,"%")
    average_reward = total_reward / Test_times   
    average_length = total_length / Test_times  
    average_distance = total_dinstance / Test_times
    average_succ = done/Test_times
    average_succ = done/Test_times
    average_done_length = done_length/done

    print("Average Reward:", average_reward)
    print("Average Length:", average_length)
    print("Average Distance:", average_distance)
    # print("Average Done Length:", average_done_length)
    print("Succesful: ", average_succ*100,"%")
# Out:
# Test_times 0
# c:\Users\EE720A\anaconda3\envs\ppotran0517\lib\site-packages\torch\__init__.py:696: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\tensor\python_tensor.cpp:453.)
#   _C._set_default_tensor_type(t)
# Current path: [16, 11, 12, 7, 8, 3, 4, 9, 8, 9, 14, 19, 18, 19, 24, 19, 18, 23, 18, 13, 12, 17, 22, 21, 16, 21, 20, 15, 16, 11, 10, 5, 0, 5, 6, 1, 0, 1, 2, 1, 6, 11, 12, 13, 8, 7, 12, 17, 16]
# Result is  1
# Episode distance: 480.0
# Episode length: 23
# Episode reward: 460.0
# path [('16', '11'), ('11', '12'), ('12', '7'), ('7', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '19'), ('19', '18'), ('18', '23'), ('23', '18'), ('18', '13'), ('13', '12'), ('12', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '1'), ('1', '0'), ('0', '1'), ('1', '2'), ('2', '1'), ('1', '6'), ('6', '11'), ('11', '12'), ('12', '13'), ('13', '8'), ('8', '7'), ('7', '12'), ('12', '17'), ('17', '16')]
# close
# Succesful:  100.0 %
# Test_times 1
# Current path: [19, 14, 9, 4, 3, 2, 3, 4, 9, 14, 19, 18, 19, 24, 19, 18, 23, 22, 17, 22, 21, 20, 15, 16, 15, 10, 11, 10, 5, 6, 1, 0, 1, 6, 11, 6, 7, 8, 13, 12, 11, 12, 13, 18, 17, 16, 11, 12, 17, 18, 19]
# Result is  1
# Episode distance: 500.0
# Episode length: 26
# Episode reward: 420.0
# path [('19', '14'), ('14', '9'), ('9', '4'), ('4', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '19'), ('19', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '1'), ('1', '0'), ('0', '1'), ('1', '6'), ('6', '11'), ('11', '6'), ('6', '7'), ('7', '8'), ('8', '13'), ('13', '12'), ('12', '11'), ('11', '12'), ('12', '13'), ('13', '18'), ('18', '17'), ('17', '16'), ('16', '11'), ('11', '12'), ('12', '17'), ('17', '18'), ('18', '19')]
# close
# Succesful:  100.0 %
# Test_times 2
# Current path: [11, 6, 1, 2, 3, 4, 9, 8, 13, 12, 17, 18, 19, 14, 19, 24, 23, 24, 19, 18, 17, 22, 17, 16, 21, 20, 15, 16, 15, 10, 11, 10, 5, 0, 1, 2, 7, 12, 11, 16, 11]
# Result is  1
# Episode distance: 400.0
# Episode length: 22
# Episode reward: 500.0
# path [('11', '6'), ('6', '1'), ('1', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '13'), ('13', '12'), ('12', '17'), ('17', '18'), ('18', '19'), ('19', '14'), ('14', '19'), ('19', '24'), ('24', '23'), ('23', '24'), ('24', '19'), ('19', '18'), ('18', '17'), ('17', '22'), ('22', '17'), ('17', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '1'), ('1', '2'), ('2', '7'), ('7', '12'), ('12', '11'), ('11', '16'), ('16', '11')]
# close
# Succesful:  100.0 %
# Test_times 3
# Current path: [15, 10, 5, 6, 1, 2, 3, 8, 3, 4, 9, 14, 13, 14, 19, 18, 19, 24, 19, 18, 23, 18, 17, 22, 21, 16, 21, 20, 21, 16, 11, 10, 5, 0, 5, 6, 7, 2, 1, 6, 11, 12, 17, 18, 13, 18, 17, 16, 11, 10, 15]
# Result is  1
# Episode distance: 500.0
# Episode length: 22
# Episode reward: 400.0
# path [('15', '10'), ('10', '5'), ('5', '6'), ('6', '1'), ('1', '2'), ('2', '3'), ('3', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '19'), ('19', '18'), ('18', '23'), ('23', '18'), ('18', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '21'), ('21', '16'), ('16', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '7'), ('7', '2'), ('2', '1'), ('1', '6'), ('6', '11'), ('11', '12'), ('12', '17'), ('17', '18'), ('18', '13'), ('13', '18'), ('18', '17'), ('17', '16'), ('16', '11'), ('11', '10'), ('10', '15')]
# close
# Succesful:  100.0 %
# Test_times 4
# Current path: [18, 13, 8, 9, 4, 3, 2, 3, 4, 9, 14, 13, 14, 19, 18, 23, 24, 23, 22, 21, 20, 15, 16, 15, 10, 11, 6, 5, 0, 1, 6, 1, 2, 1, 6, 7, 8, 7, 12, 13, 8, 7, 6, 11, 16, 17, 16, 11, 6, 7, 8, 13, 18]
# Result is  1
# Episode distance: 520.0
# Episode length: 23
# Episode reward: 400.0
# path [('18', '13'), ('13', '8'), ('8', '9'), ('9', '4'), ('4', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '22'), ('22', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '1'), ('1', '2'), ('2', '1'), ('1', '6'), ('6', '7'), ('7', '8'), ('8', '7'), ('7', '12'), ('12', '13'), ('13', '8'), ('8', '7'), ('7', '6'), ('6', '11'), ('11', '16'), ('16', '17'), ('17', '16'), ('16', '11'), ('11', '6'), ('6', '7'), ('7', '8'), ('8', '13'), ('13', '18')]
# close
# Succesful:  100.0 %
# Test_times 5
# Current path: [3, 8, 3, 4, 3, 8, 13, 14, 9, 14, 19, 18, 19, 24, 23, 18, 23, 22, 17, 22, 21, 16, 21, 20, 21, 16, 15, 16, 11, 10, 5, 6, 5, 0, 5, 6, 1, 2, 7, 6, 7, 8, 7, 12, 17, 18, 13, 8, 7, 12, 11, 16, 17, 12, 7, 8, 3]
# Result is  1
# Episode distance: 560.0
# Episode length: 28
# Episode reward: 380.0
# path [('3', '8'), ('8', '3'), ('3', '4'), ('4', '3'), ('3', '8'), ('8', '13'), ('13', '14'), ('14', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '21'), ('21', '16'), ('16', '15'), ('15', '16'), ('16', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '7'), ('7', '8'), ('8', '7'), ('7', '12'), ('12', '17'), ('17', '18'), ('18', '13'), ('13', '8'), ('8', '7'), ('7', '12'), ('12', '11'), ('11', '16'), ('16', '17'), ('17', '12'), ('12', '7'), ('7', '8'), ('8', '3')]
# close
# Succesful:  100.0 %
# Test_times 6
# Current path: [22, 17, 12, 13, 8, 3, 4, 9, 8, 13, 14, 19, 24, 23, 18, 23, 22, 21, 16, 21, 20, 15, 16, 15, 10, 11, 10, 5, 10, 11, 6, 1, 0, 1, 6, 7, 2, 7, 12, 13, 18, 13, 12, 11, 12, 17, 18, 17, 22]
# Result is  1
# Episode distance: 480.0
# Episode length: 25
# Episode reward: 440.0
# path [('22', '17'), ('17', '12'), ('12', '13'), ('13', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '13'), ('13', '14'), ('14', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '10'), ('10', '11'), ('11', '6'), ('6', '1'), ('1', '0'), ('0', '1'), ('1', '6'), ('6', '7'), ('7', '2'), ('2', '7'), ('7', '12'), ('12', '13'), ('13', '18'), ('18', '13'), ('13', '12'), ('12', '11'), ('11', '12'), ('12', '17'), ('17', '18'), ('18', '17'), ('17', '22')]
# close
# Succesful:  100.0 %
# Test_times 7
# Current path: [4, 9, 8, 3, 8, 9, 14, 19, 18, 23, 24, 23, 18, 13, 12, 17, 22, 17, 16, 21, 20, 15, 16, 11, 10, 11, 6, 5, 0, 1, 6, 1, 2, 7, 6, 7, 8, 13, 12, 7, 12, 11, 6, 7, 8, 9, 4]
# Result is  1
# Episode distance: 460.0
# Episode length: 24
# Episode reward: 460.0
# path [('4', '9'), ('9', '8'), ('8', '3'), ('3', '8'), ('8', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '18'), ('18', '13'), ('13', '12'), ('12', '17'), ('17', '22'), ('22', '17'), ('17', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '11'), ('11', '10'), ('10', '11'), ('11', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '7'), ('7', '8'), ('8', '13'), ('13', '12'), ('12', '7'), ('7', '12'), ('12', '11'), ('11', '6'), ('6', '7'), ('7', '8'), ('8', '9'), ('9', '4')]
# close
# Succesful:  100.0 %
# Test_times 8
# Current path: [7, 2, 3, 8, 3, 4, 9, 14, 13, 14, 19, 18, 23, 24, 23, 22, 17, 22, 21, 16, 15, 20, 15, 10, 11, 10, 5, 6, 5, 0, 1, 0, 5, 6, 11, 6, 7, 12, 17, 18, 13, 8, 3, 2, 7, 12, 11, 16, 11, 6, 7]
# Result is  1
# Episode distance: 500.0
# Episode length: 27
# Episode reward: 440.0
# path [('7', '2'), ('2', '3'), ('3', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '15'), ('15', '20'), ('20', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '0'), ('0', '5'), ('5', '6'), ('6', '11'), ('11', '6'), ('6', '7'), ('7', '12'), ('12', '17'), ('17', '18'), ('18', '13'), ('13', '8'), ('8', '3'), ('3', '2'), ('2', '7'), ('7', '12'), ('12', '11'), ('11', '16'), ('16', '11'), ('11', '6'), ('6', '7')]
# close
# Succesful:  100.0 %
# Test_times 9
# Current path: [14, 19, 18, 17, 12, 7, 6, 1, 2, 3, 4, 9, 4, 3, 2, 7, 12, 17, 18, 19, 24, 23, 18, 23, 22, 17, 22, 21, 16, 21, 20, 21, 16, 15, 10, 5, 0, 5, 6, 1, 0, 1, 2, 7, 12, 13, 8, 13, 12, 11, 6, 11, 16, 17, 18, 19, 14]
# Result is  1
# Episode distance: 560.0
# Episode length: 22
# Episode reward: 380.0
# path [('14', '19'), ('19', '18'), ('18', '17'), ('17', '12'), ('12', '7'), ('7', '6'), ('6', '1'), ('1', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '4'), ('4', '3'), ('3', '2'), ('2', '7'), ('7', '12'), ('12', '17'), ('17', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '21'), ('21', '16'), ('16', '15'), ('15', '10'), ('10', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '1'), ('1', '0'), ('0', '1'), ('1', '2'), ('2', '7'), ('7', '12'), ('12', '13'), ('13', '8'), ('8', '13'), ('13', '12'), ('12', '11'), ('11', '6'), ('6', '11'), ('11', '16'), ('16', '17'), ('17', '18'), ('18', '19'), ('19', '14')]
# close
# Succesful:  100.0 %
# Test_times 10
# Current path: [7, 12, 13, 8, 3, 4, 9, 8, 13, 14, 13, 18, 19, 18, 23, 24, 23, 22, 17, 16, 21, 20, 21, 16, 15, 10, 11, 10, 5, 0, 1, 6, 1, 2, 1, 6, 7, 6, 11, 12, 11, 16, 17, 12, 17, 18, 13, 12, 7]
# Result is  1
# Episode distance: 480.0
# Episode length: 27
# Episode reward: 440.0
# path [('7', '12'), ('12', '13'), ('13', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '13'), ('13', '14'), ('14', '13'), ('13', '18'), ('18', '19'), ('19', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '22'), ('22', '17'), ('17', '16'), ('16', '21'), ('21', '20'), ('20', '21'), ('21', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '1'), ('1', '2'), ('2', '1'), ('1', '6'), ('6', '7'), ('7', '6'), ('6', '11'), ('11', '12'), ('12', '11'), ('11', '16'), ('16', '17'), ('17', '12'), ('12', '17'), ('17', '18'), ('18', '13'), ('13', '12'), ('12', '7')]
# close
# Succesful:  100.0 %
# Test_times 11
# Current path: [0, 5, 6, 7, 8, 3, 4, 9, 8, 9, 14, 13, 14, 19, 18, 19, 24, 23, 24, 19, 18, 17, 22, 21, 16, 15, 20, 15, 10, 11, 12, 13, 8, 7, 6, 1, 2, 1, 6, 7, 8, 13, 18, 17, 16, 11, 12, 17, 12, 13, 8, 7, 6, 5, 0]
# Result is  1
# Episode distance: 540.0
# Episode length: 23
# Episode reward: 380.0
# path [('0', '5'), ('5', '6'), ('6', '7'), ('7', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '24'), ('24', '19'), ('19', '18'), ('18', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '15'), ('15', '20'), ('20', '15'), ('15', '10'), ('10', '11'), ('11', '12'), ('12', '13'), ('13', '8'), ('8', '7'), ('7', '6'), ('6', '1'), ('1', '2'), ('2', '1'), ('1', '6'), ('6', '7'), ('7', '8'), ('8', '13'), ('13', '18'), ('18', '17'), ('17', '16'), ('16', '11'), ('11', '12'), ('12', '17'), ('17', '12'), ('12', '13'), ('13', '8'), ('8', '7'), ('7', '6'), ('6', '5'), ('5', '0')]
# close
# Succesful:  100.0 %
# Test_times 12
# Current path: [0, 1, 6, 7, 8, 7, 2, 3, 4, 3, 2, 7, 8, 13, 14, 9, 14, 13, 18, 19, 24, 23, 18, 13, 12, 11, 16, 21, 22, 21, 20, 21, 16, 15, 10, 11, 10, 5, 0, 5, 6, 11, 16, 17, 12, 11, 6, 1, 0]
# Result is  1
# Episode distance: 480.0
# Episode length: 20
# Episode reward: 420.0
# path [('0', '1'), ('1', '6'), ('6', '7'), ('7', '8'), ('8', '7'), ('7', '2'), ('2', '3'), ('3', '4'), ('4', '3'), ('3', '2'), ('2', '7'), ('7', '8'), ('8', '13'), ('13', '14'), ('14', '9'), ('9', '14'), ('14', '13'), ('13', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '13'), ('13', '12'), ('12', '11'), ('11', '16'), ('16', '21'), ('21', '22'), ('22', '21'), ('21', '20'), ('20', '21'), ('21', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '11'), ('11', '16'), ('16', '17'), ('17', '12'), ('12', '11'), ('11', '6'), ('6', '1'), ('1', '0')]
# close
# Succesful:  100.0 %
# Test_times 13
# Current path: [20, 21, 16, 11, 6, 7, 8, 3, 8, 9, 4, 9, 14, 13, 14, 19, 14, 13, 18, 23, 24, 23, 22, 17, 22, 21, 20, 15, 10, 15, 20, 21, 16, 11, 6, 5, 0, 1, 2, 7, 12, 13, 8, 7, 12, 17, 16, 17, 18, 17, 16, 21, 20]
# Result is  1
# Episode distance: 520.0
# Episode length: 22
# Episode reward: 400.0
# path [('20', '21'), ('21', '16'), ('16', '11'), ('11', '6'), ('6', '7'), ('7', '8'), ('8', '3'), ('3', '8'), ('8', '9'), ('9', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '14'), ('14', '13'), ('13', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '20'), ('20', '15'), ('15', '10'), ('10', '15'), ('15', '20'), ('20', '21'), ('21', '16'), ('16', '11'), ('11', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '2'), ('2', '7'), ('7', '12'), ('12', '13'), ('13', '8'), ('8', '7'), ('7', '12'), ('12', '17'), ('17', '16'), ('16', '17'), ('17', '18'), ('18', '17'), ('17', '16'), ('16', '21'), ('21', '20')]
# close
# Succesful:  100.0 %
# Test_times 14
# Current path: [17, 12, 7, 8, 3, 2, 3, 4, 9, 14, 13, 12, 17, 22, 23, 24, 19, 24, 23, 22, 21, 16, 17, 12, 7, 6, 5, 10, 15, 20, 15, 10, 11, 6, 5, 0, 1, 2, 1, 6, 7, 2, 3, 8, 13, 18, 17]
# Result is  1
# Episode distance: 460.0
# Episode length: 19
# Episode reward: 480.0
# path [('17', '12'), ('12', '7'), ('7', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '12'), ('12', '17'), ('17', '22'), ('22', '23'), ('23', '24'), ('24', '19'), ('19', '24'), ('24', '23'), ('23', '22'), ('22', '21'), ('21', '16'), ('16', '17'), ('17', '12'), ('12', '7'), ('7', '6'), ('6', '5'), ('5', '10'), ('10', '15'), ('15', '20'), ('20', '15'), ('15', '10'), ('10', '11'), ('11', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '2'), ('2', '1'), ('1', '6'), ('6', '7'), ('7', '2'), ('2', '3'), ('3', '8'), ('8', '13'), ('13', '18'), ('18', '17')]
# close
# Succesful:  100.0 %
# Test_times 15
# Current path: [12, 7, 8, 3, 2, 3, 4, 3, 2, 7, 12, 17, 18, 19, 14, 9, 14, 19, 24, 19, 18, 23, 22, 17, 22, 21, 16, 15, 20, 15, 10, 5, 6, 5, 0, 1, 6, 1, 2, 7, 6, 11, 12, 17, 18, 13, 18, 17, 16, 11, 12]
# Result is  1
# Episode distance: 500.0
# Episode length: 24
# Episode reward: 440.0
# path [('12', '7'), ('7', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '3'), ('3', '2'), ('2', '7'), ('7', '12'), ('12', '17'), ('17', '18'), ('18', '19'), ('19', '14'), ('14', '9'), ('9', '14'), ('14', '19'), ('19', '24'), ('24', '19'), ('19', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '15'), ('15', '20'), ('20', '15'), ('15', '10'), ('10', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '11'), ('11', '12'), ('12', '17'), ('17', '18'), ('18', '13'), ('13', '18'), ('18', '17'), ('17', '16'), ('16', '11'), ('11', '12')]
# close
# Succesful:  100.0 %
# Test_times 16
# Current path: [16, 11, 12, 13, 14, 9, 4, 3, 2, 3, 4, 9, 14, 19, 24, 23, 22, 21, 16, 15, 20, 15, 10, 11, 10, 5, 0, 5, 6, 11, 6, 7, 8, 13, 14, 9, 4, 3, 2, 1, 2, 3, 4, 9, 14, 13, 12, 7, 8, 13, 18, 17, 16]
# Result is  1
# Episode distance: 520.0
# Episode length: 19
# Episode reward: 380.0
# path [('16', '11'), ('11', '12'), ('12', '13'), ('13', '14'), ('14', '9'), ('9', '4'), ('4', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '19'), ('19', '24'), ('24', '23'), ('23', '22'), ('22', '21'), ('21', '16'), ('16', '15'), ('15', '20'), ('20', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '11'), ('11', '6'), ('6', '7'), ('7', '8'), ('8', '13'), ('13', '14'), ('14', '9'), ('9', '4'), ('4', '3'), ('3', '2'), ('2', '1'), ('1', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '12'), ('12', '7'), ('7', '8'), ('8', '13'), ('13', '18'), ('18', '17'), ('17', '16')]
# close
# Succesful:  100.0 %
# Test_times 17
# Current path: [0, 5, 6, 11, 12, 7, 8, 3, 2, 3, 4, 3, 8, 9, 14, 13, 14, 19, 18, 19, 24, 23, 18, 19, 14, 13, 12, 17, 16, 21, 22, 21, 20, 15, 16, 17, 12, 11, 10, 5, 6, 11, 12, 7, 2, 1, 2, 3, 8, 13, 12, 11, 6, 5, 0]
# Result is  1
# Episode distance: 540.0
# Episode length: 19
# Episode reward: 360.0
# path [('0', '5'), ('5', '6'), ('6', '11'), ('11', '12'), ('12', '7'), ('7', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '3'), ('3', '8'), ('8', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '19'), ('19', '14'), ('14', '13'), ('13', '12'), ('12', '17'), ('17', '16'), ('16', '21'), ('21', '22'), ('22', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '17'), ('17', '12'), ('12', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '11'), ('11', '12'), ('12', '7'), ('7', '2'), ('2', '1'), ('1', '2'), ('2', '3'), ('3', '8'), ('8', '13'), ('13', '12'), ('12', '11'), ('11', '6'), ('6', '5'), ('5', '0')]
# close
# Succesful:  100.0 %
# Test_times 18
# Current path: [6, 7, 8, 3, 2, 3, 4, 9, 8, 9, 14, 13, 14, 19, 18, 19, 24, 23, 18, 23, 22, 17, 22, 21, 20, 15, 20, 21, 22, 17, 12, 11, 10, 11, 12, 7, 6, 5, 6, 1, 0, 1, 2, 3, 8, 13, 18, 17, 16, 11, 12, 7, 6]
# Result is  1
# Episode distance: 520.0
# Episode length: 27
# Episode reward: 420.0
# path [('6', '7'), ('7', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '20'), ('20', '15'), ('15', '20'), ('20', '21'), ('21', '22'), ('22', '17'), ('17', '12'), ('12', '11'), ('11', '10'), ('10', '11'), ('11', '12'), ('12', '7'), ('7', '6'), ('6', '5'), ('5', '6'), ('6', '1'), ('1', '0'), ('0', '1'), ('1', '2'), ('2', '3'), ('3', '8'), ('8', '13'), ('13', '18'), ('18', '17'), ('17', '16'), ('16', '11'), ('11', '12'), ('12', '7'), ('7', '6')]
# close
# Succesful:  100.0 %
# Test_times 19
# Current path: [21, 16, 11, 6, 7, 8, 3, 4, 9, 14, 19, 18, 19, 24, 19, 18, 23, 22, 17, 22, 21, 16, 15, 20, 15, 10, 5, 6, 5, 0, 1, 6, 7, 2, 7, 12, 13, 8, 7, 12, 11, 12, 17, 18, 17, 22, 21]
# Result is  1
# Episode distance: 460.0
# Episode length: 25
# Episode reward: 460.0
# path [('21', '16'), ('16', '11'), ('11', '6'), ('6', '7'), ('7', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '19'), ('19', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '15'), ('15', '20'), ('20', '15'), ('15', '10'), ('10', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '7'), ('7', '2'), ('2', '7'), ('7', '12'), ('12', '13'), ('13', '8'), ('8', '7'), ('7', '12'), ('12', '11'), ('11', '12'), ('12', '17'), ('17', '18'), ('18', '17'), ('17', '22'), ('22', '21')]
# close
# Succesful:  100.0 %
# Test_times 20
# Current path: [7, 8, 3, 2, 3, 8, 9, 4, 9, 14, 13, 18, 19, 24, 23, 18, 23, 22, 17, 22, 21, 16, 21, 20, 21, 16, 15, 10, 5, 0, 5, 10, 15, 16, 11, 6, 1, 2, 7, 12, 13, 8, 7, 12, 17, 16, 17, 18, 13, 8, 7]
# Result is  1
# Episode distance: 500.0
# Episode length: 27
# Episode reward: 440.0
# path [('7', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '8'), ('8', '9'), ('9', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '21'), ('21', '16'), ('16', '15'), ('15', '10'), ('10', '5'), ('5', '0'), ('0', '5'), ('5', '10'), ('10', '15'), ('15', '16'), ('16', '11'), ('11', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '12'), ('12', '13'), ('13', '8'), ('8', '7'), ('7', '12'), ('12', '17'), ('17', '16'), ('16', '17'), ('17', '18'), ('18', '13'), ('13', '8'), ('8', '7')]
# close
# Succesful:  100.0 %
# Test_times 21
# Current path: [7, 2, 3, 8, 3, 4, 9, 8, 9, 14, 19, 18, 19, 24, 19, 18, 17, 22, 23, 22, 17, 16, 21, 20, 15, 10, 11, 10, 5, 0, 1, 6, 7, 6, 11, 6, 7, 12, 13, 8, 13, 18, 17, 16, 11, 6, 7]
# Result is  1
# Episode distance: 460.0
# Episode length: 24
# Episode reward: 440.0
# path [('7', '2'), ('2', '3'), ('3', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '19'), ('19', '18'), ('18', '17'), ('17', '22'), ('22', '23'), ('23', '22'), ('22', '17'), ('17', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '7'), ('7', '6'), ('6', '11'), ('11', '6'), ('6', '7'), ('7', '12'), ('12', '13'), ('13', '8'), ('8', '13'), ('13', '18'), ('18', '17'), ('17', '16'), ('16', '11'), ('11', '6'), ('6', '7')]
# close
# Succesful:  100.0 %
# Test_times 22
# Current path: [14, 19, 18, 17, 12, 13, 8, 3, 2, 3, 8, 9, 4, 9, 8, 13, 12, 17, 18, 19, 24, 23, 18, 23, 22, 17, 22, 21, 16, 21, 20, 15, 16, 15, 10, 11, 10, 5, 10, 11, 12, 7, 2, 1, 0, 1, 2, 7, 12, 11, 6, 11, 16, 17, 18, 19, 14]
# Result is  1
# Episode distance: 560.0
# Episode length: 20
# Episode reward: 360.0
# path [('14', '19'), ('19', '18'), ('18', '17'), ('17', '12'), ('12', '13'), ('13', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '8'), ('8', '9'), ('9', '4'), ('4', '9'), ('9', '8'), ('8', '13'), ('13', '12'), ('12', '17'), ('17', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '10'), ('10', '11'), ('11', '12'), ('12', '7'), ('7', '2'), ('2', '1'), ('1', '0'), ('0', '1'), ('1', '2'), ('2', '7'), ('7', '12'), ('12', '11'), ('11', '6'), ('6', '11'), ('11', '16'), ('16', '17'), ('17', '18'), ('18', '19'), ('19', '14')]
# close
# Succesful:  100.0 %
# Test_times 23
# Current path: [6, 7, 2, 3, 4, 3, 2, 7, 8, 13, 14, 9, 14, 19, 24, 23, 18, 17, 22, 21, 16, 21, 20, 21, 16, 15, 10, 11, 10, 5, 6, 1, 0, 1, 6, 11, 12, 7, 12, 13, 18, 17, 16, 11, 12, 17, 12, 7, 6]
# Result is  1
# Episode distance: 480.0
# Episode length: 26
# Episode reward: 460.0
# path [('6', '7'), ('7', '2'), ('2', '3'), ('3', '4'), ('4', '3'), ('3', '2'), ('2', '7'), ('7', '8'), ('8', '13'), ('13', '14'), ('14', '9'), ('9', '14'), ('14', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '21'), ('21', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '1'), ('1', '0'), ('0', '1'), ('1', '6'), ('6', '11'), ('11', '12'), ('12', '7'), ('7', '12'), ('12', '13'), ('13', '18'), ('18', '17'), ('17', '16'), ('16', '11'), ('11', '12'), ('12', '17'), ('17', '12'), ('12', '7'), ('7', '6')]
# close
# Succesful:  100.0 %
# Test_times 24
# Current path: [11, 12, 7, 8, 3, 4, 9, 14, 19, 18, 19, 24, 19, 18, 23, 22, 17, 22, 21, 20, 15, 16, 11, 10, 5, 6, 5, 0, 5, 6, 1, 2, 7, 12, 11, 6, 11, 12, 13, 8, 7, 12, 17, 16, 17, 18, 17, 12, 11]
# Result is  1
# Episode distance: 480.0
# Episode length: 26
# Episode reward: 440.0
# path [('11', '12'), ('12', '7'), ('7', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '19'), ('19', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '12'), ('12', '11'), ('11', '6'), ('6', '11'), ('11', '12'), ('12', '13'), ('13', '8'), ('8', '7'), ('7', '12'), ('12', '17'), ('17', '16'), ('16', '17'), ('17', '18'), ('18', '17'), ('17', '12'), ('12', '11')]
# close
# Succesful:  100.0 %
# Test_times 25
# Current path: [3, 8, 3, 4, 9, 8, 9, 14, 19, 24, 23, 18, 23, 22, 23, 18, 17, 12, 11, 16, 21, 20, 15, 16, 15, 10, 11, 6, 5, 6, 1, 0, 1, 6, 7, 2, 7, 8, 7, 12, 13, 8, 3]
# Result is  1
# Episode distance: 420.0
# Episode length: 25
# Episode reward: 480.0
# path [('3', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '9'), ('9', '14'), ('14', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '23'), ('23', '18'), ('18', '17'), ('17', '12'), ('12', '11'), ('11', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '6'), ('6', '5'), ('5', '6'), ('6', '1'), ('1', '0'), ('0', '1'), ('1', '6'), ('6', '7'), ('7', '2'), ('2', '7'), ('7', '8'), ('8', '7'), ('7', '12'), ('12', '13'), ('13', '8'), ('8', '3')]
# close
# Succesful:  100.0 %
# Test_times 26
# Current path: [9, 8, 3, 8, 9, 4, 9, 14, 13, 14, 19, 24, 23, 18, 23, 22, 17, 22, 21, 16, 21, 20, 15, 10, 11, 12, 7, 2, 1, 0, 5, 0, 1, 6, 7, 8, 7, 12, 13, 18, 13, 12, 17, 16, 17, 12, 7, 8, 9]
# Result is  1
# Episode distance: 480.0
# Episode length: 24
# Episode reward: 420.0
# path [('9', '8'), ('8', '3'), ('3', '8'), ('8', '9'), ('9', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '10'), ('10', '11'), ('11', '12'), ('12', '7'), ('7', '2'), ('2', '1'), ('1', '0'), ('0', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '7'), ('7', '8'), ('8', '7'), ('7', '12'), ('12', '13'), ('13', '18'), ('18', '13'), ('13', '12'), ('12', '17'), ('17', '16'), ('16', '17'), ('17', '12'), ('12', '7'), ('7', '8'), ('8', '9')]
# close
# Succesful:  100.0 %
# Test_times 27
# Current path: [5, 0, 1, 2, 3, 8, 7, 12, 13, 14, 9, 4, 9, 14, 19, 18, 23, 24, 23, 22, 17, 22, 21, 20, 21, 22, 17, 16, 15, 10, 11, 10, 5, 6, 1, 2, 7, 2, 1, 6, 11, 16, 17, 12, 17, 18, 17, 16, 11, 6, 5]
# Result is  1
# Episode distance: 500.0
# Episode length: 21
# Episode reward: 420.0
# path [('5', '0'), ('0', '1'), ('1', '2'), ('2', '3'), ('3', '8'), ('8', '7'), ('7', '12'), ('12', '13'), ('13', '14'), ('14', '9'), ('9', '4'), ('4', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '20'), ('20', '21'), ('21', '22'), ('22', '17'), ('17', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '2'), ('2', '1'), ('1', '6'), ('6', '11'), ('11', '16'), ('16', '17'), ('17', '12'), ('12', '17'), ('17', '18'), ('18', '17'), ('17', '16'), ('16', '11'), ('11', '6'), ('6', '5')]
# close
# Succesful:  100.0 %
# Test_times 28
# Current path: [7, 8, 3, 4, 9, 8, 13, 18, 19, 14, 19, 24, 19, 18, 17, 22, 23, 22, 21, 16, 21, 20, 15, 16, 15, 10, 5, 6, 5, 0, 1, 6, 1, 2, 1, 6, 7, 6, 11, 12, 7, 12, 13, 12, 11, 16, 11, 12, 17, 12, 7]
# Result is  1
# Episode distance: 500.0
# Episode length: 25
# Episode reward: 440.0
# path [('7', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '13'), ('13', '18'), ('18', '19'), ('19', '14'), ('14', '19'), ('19', '24'), ('24', '19'), ('19', '18'), ('18', '17'), ('17', '22'), ('22', '23'), ('23', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '1'), ('1', '2'), ('2', '1'), ('1', '6'), ('6', '7'), ('7', '6'), ('6', '11'), ('11', '12'), ('12', '7'), ('7', '12'), ('12', '13'), ('13', '12'), ('12', '11'), ('11', '16'), ('16', '11'), ('11', '12'), ('12', '17'), ('17', '12'), ('12', '7')]
# close
# Succesful:  100.0 %
# Test_times 29
# Current path: [19, 14, 9, 8, 3, 4, 9, 14, 13, 18, 19, 24, 23, 18, 23, 22, 17, 22, 21, 16, 21, 20, 21, 16, 11, 10, 15, 10, 11, 6, 5, 6, 1, 0, 1, 6, 7, 2, 7, 8, 7, 12, 11, 16, 17, 12, 17, 18, 19]
# Result is  1
# Episode distance: 480.0
# Episode length: 26
# Episode reward: 460.0
# path [('19', '14'), ('14', '9'), ('9', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '21'), ('21', '16'), ('16', '11'), ('11', '10'), ('10', '15'), ('15', '10'), ('10', '11'), ('11', '6'), ('6', '5'), ('5', '6'), ('6', '1'), ('1', '0'), ('0', '1'), ('1', '6'), ('6', '7'), ('7', '2'), ('2', '7'), ('7', '8'), ('8', '7'), ('7', '12'), ('12', '11'), ('11', '16'), ('16', '17'), ('17', '12'), ('12', '17'), ('17', '18'), ('18', '19')]
# close
# Succesful:  100.0 %
# Test_times 30
# Current path: [8, 3, 2, 3, 4, 3, 8, 9, 8, 3, 2, 1, 0, 5, 10, 11, 12, 13, 14, 19, 18, 23, 24, 23, 22, 17, 22, 21, 16, 15, 20, 15, 10, 5, 6, 1, 6, 7, 6, 5, 10, 11, 16, 11, 12, 13, 18, 13, 12, 17, 16, 11, 10, 5, 0, 1, 2, 3, 8]
# Result is  1
# Episode distance: 580.0
# Episode length: 21
# Episode reward: 320.0
# path [('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '3'), ('3', '8'), ('8', '9'), ('9', '8'), ('8', '3'), ('3', '2'), ('2', '1'), ('1', '0'), ('0', '5'), ('5', '10'), ('10', '11'), ('11', '12'), ('12', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '15'), ('15', '20'), ('20', '15'), ('15', '10'), ('10', '5'), ('5', '6'), ('6', '1'), ('1', '6'), ('6', '7'), ('7', '6'), ('6', '5'), ('5', '10'), ('10', '11'), ('11', '16'), ('16', '11'), ('11', '12'), ('12', '13'), ('13', '18'), ('18', '13'), ('13', '12'), ('12', '17'), ('17', '16'), ('16', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '1'), ('1', '2'), ('2', '3'), ('3', '8')]
# close
# Succesful:  100.0 %
# Test_times 31
# Current path: [20, 21, 16, 11, 12, 13, 8, 7, 2, 3, 2, 7, 8, 9, 4, 9, 14, 13, 14, 19, 18, 23, 24, 23, 22, 17, 22, 21, 16, 11, 10, 15, 10, 5, 0, 1, 6, 7, 8, 13, 18, 17, 16, 17, 12, 11, 16, 21, 20]
# Result is  1
# Episode distance: 480.0
# Episode length: 21
# Episode reward: 440.0
# path [('20', '21'), ('21', '16'), ('16', '11'), ('11', '12'), ('12', '13'), ('13', '8'), ('8', '7'), ('7', '2'), ('2', '3'), ('3', '2'), ('2', '7'), ('7', '8'), ('8', '9'), ('9', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '11'), ('11', '10'), ('10', '15'), ('15', '10'), ('10', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '7'), ('7', '8'), ('8', '13'), ('13', '18'), ('18', '17'), ('17', '16'), ('16', '17'), ('17', '12'), ('12', '11'), ('11', '16'), ('16', '21'), ('21', '20')]
# close
# Succesful:  100.0 %
# Test_times 32
# Current path: [0, 1, 2, 3, 8, 3, 4, 9, 8, 9, 14, 9, 8, 13, 18, 19, 24, 23, 24, 19, 18, 17, 22, 21, 16, 21, 20, 15, 16, 15, 10, 11, 10, 5, 0, 1, 6, 7, 2, 7, 12, 13, 12, 7, 6, 11, 16, 11, 6, 1, 0]
# Result is  1
# Episode distance: 500.0
# Episode length: 25
# Episode reward: 420.0
# path [('0', '1'), ('1', '2'), ('2', '3'), ('3', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '9'), ('9', '14'), ('14', '9'), ('9', '8'), ('8', '13'), ('13', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '24'), ('24', '19'), ('19', '18'), ('18', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '7'), ('7', '2'), ('2', '7'), ('7', '12'), ('12', '13'), ('13', '12'), ('12', '7'), ('7', '6'), ('6', '11'), ('11', '16'), ('16', '11'), ('11', '6'), ('6', '1'), ('1', '0')]
# close
# Succesful:  100.0 %
# Test_times 33
# Current path: [4, 3, 2, 3, 4, 9, 8, 9, 14, 13, 18, 23, 24, 19, 24, 23, 22, 17, 16, 21, 20, 15, 16, 15, 10, 11, 6, 5, 0, 5, 6, 1, 2, 1, 6, 7, 6, 11, 12, 17, 18, 13, 8, 13, 18, 17, 16, 11, 6, 1, 2, 3, 4]
# Result is  1
# Episode distance: 520.0
# Episode length: 21
# Episode reward: 380.0
# path [('4', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '9'), ('9', '14'), ('14', '13'), ('13', '18'), ('18', '23'), ('23', '24'), ('24', '19'), ('19', '24'), ('24', '23'), ('23', '22'), ('22', '17'), ('17', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '6'), ('6', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '1'), ('1', '2'), ('2', '1'), ('1', '6'), ('6', '7'), ('7', '6'), ('6', '11'), ('11', '12'), ('12', '17'), ('17', '18'), ('18', '13'), ('13', '8'), ('8', '13'), ('13', '18'), ('18', '17'), ('17', '16'), ('16', '11'), ('11', '6'), ('6', '1'), ('1', '2'), ('2', '3'), ('3', '4')]
# close
# Succesful:  100.0 %
# Test_times 34
# Current path: [21, 16, 11, 6, 7, 8, 7, 2, 3, 2, 7, 8, 9, 4, 9, 14, 9, 8, 7, 6, 11, 16, 17, 18, 19, 24, 23, 18, 23, 22, 21, 20, 15, 16, 15, 10, 11, 10, 5, 0, 1, 6, 5, 0, 1, 2, 7, 8, 13, 8, 7, 6, 11, 16, 17, 12, 17, 16, 21]
# Result is  1
# Episode distance: 580.0
# Episode length: 24
# Episode reward: 340.0
# path [('21', '16'), ('16', '11'), ('11', '6'), ('6', '7'), ('7', '8'), ('8', '7'), ('7', '2'), ('2', '3'), ('3', '2'), ('2', '7'), ('7', '8'), ('8', '9'), ('9', '4'), ('4', '9'), ('9', '14'), ('14', '9'), ('9', '8'), ('8', '7'), ('7', '6'), ('6', '11'), ('11', '16'), ('16', '17'), ('17', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '2'), ('2', '7'), ('7', '8'), ('8', '13'), ('13', '8'), ('8', '7'), ('7', '6'), ('6', '11'), ('11', '16'), ('16', '17'), ('17', '12'), ('12', '17'), ('17', '16'), ('16', '21')]
# close
# Succesful:  100.0 %
# Test_times 35
# Current path: [9, 8, 3, 4, 9, 14, 19, 18, 19, 24, 23, 18, 23, 22, 17, 22, 21, 16, 21, 20, 21, 16, 15, 10, 11, 6, 5, 0, 5, 6, 1, 2, 7, 6, 7, 8, 7, 12, 13, 8, 13, 18, 17, 18, 13, 8, 9]
# Result is  1
# Episode distance: 460.0
# Episode length: 29
# Episode reward: 460.0
# path [('9', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '21'), ('21', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '6'), ('6', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '7'), ('7', '8'), ('8', '7'), ('7', '12'), ('12', '13'), ('13', '8'), ('8', '13'), ('13', '18'), ('18', '17'), ('17', '18'), ('18', '13'), ('13', '8'), ('8', '9')]
# close
# Succesful:  100.0 %
# Test_times 36
# Current path: [8, 9, 4, 3, 2, 3, 4, 9, 14, 13, 14, 19, 18, 19, 24, 23, 18, 23, 22, 17, 22, 21, 20, 15, 20, 21, 22, 17, 18, 19, 14, 13, 12, 11, 10, 5, 6, 5, 0, 1, 6, 7, 8, 7, 12, 11, 6, 7, 8, 9, 14, 19, 18, 17, 16, 17, 18, 19, 14, 9, 8]
# Result is  1
# Episode distance: 600.0
# Episode length: 25
# Episode reward: 300.0
# path [('8', '9'), ('9', '4'), ('4', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '20'), ('20', '15'), ('15', '20'), ('20', '21'), ('21', '22'), ('22', '17'), ('17', '18'), ('18', '19'), ('19', '14'), ('14', '13'), ('13', '12'), ('12', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '7'), ('7', '8'), ('8', '7'), ('7', '12'), ('12', '11'), ('11', '6'), ('6', '7'), ('7', '8'), ('8', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '17'), ('17', '16'), ('16', '17'), ('17', '18'), ('18', '19'), ('19', '14'), ('14', '9'), ('9', '8')]
# close
# Succesful:  100.0 %
# Test_times 37
# Current path: [22, 17, 12, 7, 8, 3, 2, 3, 4, 9, 14, 13, 14, 19, 24, 23, 18, 13, 12, 17, 22, 21, 16, 21, 20, 15, 16, 15, 10, 5, 6, 1, 0, 1, 2, 1, 6, 7, 8, 13, 8, 7, 6, 11, 16, 17, 22]
# Result is  1
# Episode distance: 460.0
# Episode length: 25
# Episode reward: 480.0
# path [('22', '17'), ('17', '12'), ('12', '7'), ('7', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '13'), ('13', '12'), ('12', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '5'), ('5', '6'), ('6', '1'), ('1', '0'), ('0', '1'), ('1', '2'), ('2', '1'), ('1', '6'), ('6', '7'), ('7', '8'), ('8', '13'), ('13', '8'), ('8', '7'), ('7', '6'), ('6', '11'), ('11', '16'), ('16', '17'), ('17', '22')]
# close
# Succesful:  100.0 %
# Test_times 38
# Current path: [17, 18, 13, 12, 7, 2, 3, 4, 9, 14, 19, 18, 23, 24, 23, 22, 17, 22, 21, 16, 21, 20, 15, 16, 15, 10, 11, 10, 5, 10, 11, 16, 17, 18, 13, 12, 7, 2, 1, 0, 1, 6, 7, 8, 7, 12, 13, 18, 17]
# Result is  1
# Episode distance: 480.0
# Episode length: 22
# Episode reward: 420.0
# path [('17', '18'), ('18', '13'), ('13', '12'), ('12', '7'), ('7', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '10'), ('10', '11'), ('11', '16'), ('16', '17'), ('17', '18'), ('18', '13'), ('13', '12'), ('12', '7'), ('7', '2'), ('2', '1'), ('1', '0'), ('0', '1'), ('1', '6'), ('6', '7'), ('7', '8'), ('8', '7'), ('7', '12'), ('12', '13'), ('13', '18'), ('18', '17')]
# close
# Succesful:  100.0 %
# Test_times 39
# Current path: [9, 4, 3, 8, 3, 4, 9, 14, 13, 14, 19, 18, 19, 24, 23, 18, 23, 22, 21, 16, 21, 20, 15, 16, 11, 10, 5, 6, 5, 0, 5, 6, 1, 2, 7, 6, 7, 8, 7, 6, 11, 16, 17, 12, 13, 18, 17, 12, 13, 14, 9]
# Result is  1
# Episode distance: 500.0
# Episode length: 28
# Episode reward: 440.0
# path [('9', '4'), ('4', '3'), ('3', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '7'), ('7', '8'), ('8', '7'), ('7', '6'), ('6', '11'), ('11', '16'), ('16', '17'), ('17', '12'), ('12', '13'), ('13', '18'), ('18', '17'), ('17', '12'), ('12', '13'), ('13', '14'), ('14', '9')]
# close
# Succesful:  100.0 %
# Test_times 40
# Current path: [18, 17, 12, 13, 14, 9, 8, 3, 2, 3, 8, 9, 4, 9, 14, 13, 12, 17, 18, 19, 18, 23, 24, 23, 22, 17, 22, 21, 20, 15, 16, 15, 10, 11, 10, 5, 0, 1, 6, 5, 0, 1, 2, 1, 0, 5, 10, 11, 12, 7, 12, 17, 16, 11, 12, 17, 18]
# Result is  1
# Episode distance: 560.0
# Episode length: 22
# Episode reward: 340.0
# path [('18', '17'), ('17', '12'), ('12', '13'), ('13', '14'), ('14', '9'), ('9', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '8'), ('8', '9'), ('9', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '12'), ('12', '17'), ('17', '18'), ('18', '19'), ('19', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '2'), ('2', '1'), ('1', '0'), ('0', '5'), ('5', '10'), ('10', '11'), ('11', '12'), ('12', '7'), ('7', '12'), ('12', '17'), ('17', '16'), ('16', '11'), ('11', '12'), ('12', '17'), ('17', '18')]
# close
# Succesful:  100.0 %
# Test_times 41
# Current path: [4, 3, 8, 7, 8, 3, 2, 3, 4, 9, 8, 9, 14, 9, 8, 7, 6, 11, 16, 21, 22, 23, 18, 19, 18, 23, 24, 23, 22, 21, 20, 15, 16, 15, 10, 11, 10, 5, 0, 5, 10, 11, 6, 1, 2, 1, 6, 7, 12, 13, 8, 7, 12, 11, 16, 17, 12, 7, 8, 3, 4]
# Result is  1
# Episode distance: 600.0
# Episode length: 22
# Episode reward: 320.0
# path [('4', '3'), ('3', '8'), ('8', '7'), ('7', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '9'), ('9', '14'), ('14', '9'), ('9', '8'), ('8', '7'), ('7', '6'), ('6', '11'), ('11', '16'), ('16', '21'), ('21', '22'), ('22', '23'), ('23', '18'), ('18', '19'), ('19', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '22'), ('22', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '5'), ('5', '10'), ('10', '11'), ('11', '6'), ('6', '1'), ('1', '2'), ('2', '1'), ('1', '6'), ('6', '7'), ('7', '12'), ('12', '13'), ('13', '8'), ('8', '7'), ('7', '12'), ('12', '11'), ('11', '16'), ('16', '17'), ('17', '12'), ('12', '7'), ('7', '8'), ('8', '3'), ('3', '4')]
# close
# Succesful:  100.0 %
# Test_times 42
# Current path: [21, 22, 17, 12, 13, 8, 3, 2, 3, 8, 9, 4, 9, 14, 9, 8, 13, 18, 19, 24, 23, 18, 23, 22, 21, 16, 21, 20, 15, 16, 11, 10, 5, 0, 5, 6, 5, 0, 1, 2, 1, 0, 5, 6, 7, 6, 11, 16, 21, 22, 17, 18, 17, 22, 21]
# Result is  1
# Episode distance: 540.0
# Episode length: 23
# Episode reward: 360.0
# path [('21', '22'), ('22', '17'), ('17', '12'), ('12', '13'), ('13', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '8'), ('8', '9'), ('9', '4'), ('4', '9'), ('9', '14'), ('14', '9'), ('9', '8'), ('8', '13'), ('13', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '2'), ('2', '1'), ('1', '0'), ('0', '5'), ('5', '6'), ('6', '7'), ('7', '6'), ('6', '11'), ('11', '16'), ('16', '21'), ('21', '22'), ('22', '17'), ('17', '18'), ('18', '17'), ('17', '22'), ('22', '21')]
# close
# Succesful:  100.0 %
# Test_times 43
# Current path: [18, 13, 8, 3, 4, 9, 8, 9, 14, 13, 14, 19, 18, 19, 24, 23, 18, 23, 22, 17, 16, 15, 20, 21, 20, 15, 10, 11, 10, 5, 0, 1, 6, 11, 16, 17, 22, 23, 18, 13, 8, 7, 2, 7, 8, 13, 18, 23, 22, 17, 16, 11, 12, 11, 16, 17, 22, 23, 18]
# Result is  1
# Episode distance: 580.0
# Episode length: 24
# Episode reward: 320.0
# path [('18', '13'), ('13', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '16'), ('16', '15'), ('15', '20'), ('20', '21'), ('21', '20'), ('20', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '11'), ('11', '16'), ('16', '17'), ('17', '22'), ('22', '23'), ('23', '18'), ('18', '13'), ('13', '8'), ('8', '7'), ('7', '2'), ('2', '7'), ('7', '8'), ('8', '13'), ('13', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '16'), ('16', '11'), ('11', '12'), ('12', '11'), ('11', '16'), ('16', '17'), ('17', '22'), ('22', '23'), ('23', '18')]
# close
# Succesful:  100.0 %
# Test_times 44
# Current path: [23, 18, 13, 12, 7, 2, 3, 4, 9, 8, 13, 14, 19, 14, 13, 18, 23, 24, 23, 22, 17, 22, 21, 16, 21, 20, 15, 10, 11, 16, 17, 12, 7, 6, 5, 0, 1, 6, 1, 2, 7, 12, 13, 18, 23]
# Result is  1
# Episode distance: 440.0
# Episode length: 21
# Episode reward: 460.0
# path [('23', '18'), ('18', '13'), ('13', '12'), ('12', '7'), ('7', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '13'), ('13', '14'), ('14', '19'), ('19', '14'), ('14', '13'), ('13', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '10'), ('10', '11'), ('11', '16'), ('16', '17'), ('17', '12'), ('12', '7'), ('7', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '12'), ('12', '13'), ('13', '18'), ('18', '23')]
# close
# Succesful:  100.0 %
# Test_times 45
# Current path: [6, 7, 8, 7, 2, 3, 2, 7, 8, 9, 4, 9, 14, 13, 12, 17, 18, 23, 24, 19, 24, 23, 22, 17, 22, 21, 16, 21, 20, 15, 10, 11, 10, 5, 6, 5, 0, 1, 6, 1, 2, 7, 12, 11, 6, 11, 16, 11, 6]
# Result is  1
# Episode distance: 480.0
# Episode length: 25
# Episode reward: 460.0
# path [('6', '7'), ('7', '8'), ('8', '7'), ('7', '2'), ('2', '3'), ('3', '2'), ('2', '7'), ('7', '8'), ('8', '9'), ('9', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '12'), ('12', '17'), ('17', '18'), ('18', '23'), ('23', '24'), ('24', '19'), ('19', '24'), ('24', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '12'), ('12', '11'), ('11', '6'), ('6', '11'), ('11', '16'), ('16', '11'), ('11', '6')]
# close
# Succesful:  100.0 %
# Test_times 46
# Current path: [18, 17, 12, 7, 2, 3, 4, 9, 8, 9, 14, 13, 12, 17, 18, 19, 24, 23, 18, 23, 22, 17, 22, 21, 16, 15, 20, 15, 10, 11, 10, 5, 6, 7, 2, 1, 0, 1, 2, 7, 6, 11, 12, 17, 18]
# Result is  1
# Episode distance: 440.0
# Episode length: 23
# Episode reward: 460.0
# path [('18', '17'), ('17', '12'), ('12', '7'), ('7', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '9'), ('9', '14'), ('14', '13'), ('13', '12'), ('12', '17'), ('17', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '15'), ('15', '20'), ('20', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '7'), ('7', '2'), ('2', '1'), ('1', '0'), ('0', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '11'), ('11', '12'), ('12', '17'), ('17', '18')]
# close
# Succesful:  100.0 %
# Test_times 47
# Current path: [18, 13, 12, 7, 2, 3, 2, 7, 12, 13, 14, 9, 4, 9, 14, 19, 18, 19, 24, 23, 18, 23, 22, 17, 22, 21, 22, 17, 16, 15, 20, 15, 16, 11, 10, 5, 6, 5, 0, 5, 6, 1, 2, 7, 6, 7, 8, 7, 6, 11, 12, 17, 18]
# Result is  1
# Episode distance: 520.0
# Episode length: 23
# Episode reward: 420.0
# path [('18', '13'), ('13', '12'), ('12', '7'), ('7', '2'), ('2', '3'), ('3', '2'), ('2', '7'), ('7', '12'), ('12', '13'), ('13', '14'), ('14', '9'), ('9', '4'), ('4', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '22'), ('22', '17'), ('17', '16'), ('16', '15'), ('15', '20'), ('20', '15'), ('15', '16'), ('16', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '7'), ('7', '8'), ('8', '7'), ('7', '6'), ('6', '11'), ('11', '12'), ('12', '17'), ('17', '18')]
# close
# Succesful:  100.0 %
# Test_times 48
# ...
# Result is  1
# Episode distance: 620.0
# Episode length: 28
# Episode reward: 320.0
# path [('4', '9'), ('9', '8'), ('8', '7'), ('7', '2'), ('2', '3'), ('3', '2'), ('2', '7'), ('7', '8'), ('8', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '15'), ('15', '20'), ('20', '15'), ('15', '10'), ('10', '5'), ('5', '6'), ('6', '1'), ('1', '0'), ('0', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '7'), ('7', '12'), ('12', '7'), ('7', '8'), ('8', '13'), ('13', '8'), ('8', '7'), ('7', '12'), ('12', '11'), ('11', '12'), ('12', '7'), ('7', '8'), ('8', '13'), ('13', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '16'), ('16', '11'), ('11', '12'), ('12', '17'), ('17', '12'), ('12', '7'), ('7', '8'), ('8', '9'), ('9', '4')]
# close
# Succesful:  100.0 %
# Test_times 85
# Current path: [11, 6, 7, 8, 3, 4, 9, 14, 13, 14, 19, 24, 23, 18, 23, 22, 17, 22, 21, 16, 21, 20, 21, 16, 11, 6, 5, 10, 15, 10, 5, 6, 1, 0, 1, 6, 7, 2, 7, 12, 13, 18, 13, 12, 11, 16, 17, 12, 17, 18, 13, 12, 11]
# Result is  1
# Episode distance: 520.0
# Episode length: 25
# Episode reward: 400.0
# path [('11', '6'), ('6', '7'), ('7', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '21'), ('21', '16'), ('16', '11'), ('11', '6'), ('6', '5'), ('5', '10'), ('10', '15'), ('15', '10'), ('10', '5'), ('5', '6'), ('6', '1'), ('1', '0'), ('0', '1'), ('1', '6'), ('6', '7'), ('7', '2'), ('2', '7'), ('7', '12'), ('12', '13'), ('13', '18'), ('18', '13'), ('13', '12'), ('12', '11'), ('11', '16'), ('16', '17'), ('17', '12'), ('12', '17'), ('17', '18'), ('18', '13'), ('13', '12'), ('12', '11')]
# close
# Succesful:  100.0 %
# Test_times 86
# Current path: [16, 17, 12, 7, 8, 3, 2, 3, 4, 3, 8, 13, 14, 9, 14, 19, 18, 19, 24, 19, 18, 23, 22, 17, 22, 21, 16, 21, 20, 15, 16, 15, 10, 15, 16, 17, 12, 7, 6, 5, 0, 5, 6, 1, 2, 3, 8, 13, 12, 13, 18, 13, 12, 11, 6, 7, 12, 17, 18, 17, 16]
# Result is  1
# Episode distance: 600.0
# Episode length: 26
# Episode reward: 340.0
# path [('16', '17'), ('17', '12'), ('12', '7'), ('7', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '3'), ('3', '8'), ('8', '13'), ('13', '14'), ('14', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '19'), ('19', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '15'), ('15', '16'), ('16', '17'), ('17', '12'), ('12', '7'), ('7', '6'), ('6', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '1'), ('1', '2'), ('2', '3'), ('3', '8'), ('8', '13'), ('13', '12'), ('12', '13'), ('13', '18'), ('18', '13'), ('13', '12'), ('12', '11'), ('11', '6'), ('6', '7'), ('7', '12'), ('12', '17'), ('17', '18'), ('18', '17'), ('17', '16')]
# close
# Succesful:  100.0 %
# Test_times 87
# Current path: [9, 8, 3, 8, 9, 4, 9, 8, 13, 14, 19, 18, 23, 24, 23, 22, 17, 16, 21, 16, 15, 20, 15, 16, 11, 10, 11, 6, 5, 0, 1, 6, 1, 2, 7, 6, 7, 8, 7, 12, 7, 8, 13, 18, 13, 8, 7, 12, 11, 12, 17, 12, 7, 8, 9]
# Result is  1
# Episode distance: 540.0
# Episode length: 24
# Episode reward: 360.0
# path [('9', '8'), ('8', '3'), ('3', '8'), ('8', '9'), ('9', '4'), ('4', '9'), ('9', '8'), ('8', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '22'), ('22', '17'), ('17', '16'), ('16', '21'), ('21', '16'), ('16', '15'), ('15', '20'), ('20', '15'), ('15', '16'), ('16', '11'), ('11', '10'), ('10', '11'), ('11', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '7'), ('7', '8'), ('8', '7'), ('7', '12'), ('12', '7'), ('7', '8'), ('8', '13'), ('13', '18'), ('18', '13'), ('13', '8'), ('8', '7'), ('7', '12'), ('12', '11'), ('11', '12'), ('12', '17'), ('17', '12'), ('12', '7'), ('7', '8'), ('8', '9')]
# close
# Succesful:  100.0 %
# Test_times 88
# Current path: [2, 3, 8, 3, 4, 3, 8, 9, 14, 13, 14, 19, 18, 19, 24, 19, 18, 23, 22, 21, 16, 21, 20, 21, 16, 15, 10, 11, 10, 5, 10, 11, 6, 1, 0, 1, 2, 7, 6, 7, 8, 13, 12, 11, 12, 13, 18, 13, 12, 11, 16, 17, 16, 11, 6, 1, 2]
# Result is  1
# Episode distance: 560.0
# Episode length: 28
# Episode reward: 360.0
# path [('2', '3'), ('3', '8'), ('8', '3'), ('3', '4'), ('4', '3'), ('3', '8'), ('8', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '19'), ('19', '18'), ('18', '23'), ('23', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '21'), ('21', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '10'), ('10', '11'), ('11', '6'), ('6', '1'), ('1', '0'), ('0', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '7'), ('7', '8'), ('8', '13'), ('13', '12'), ('12', '11'), ('11', '12'), ('12', '13'), ('13', '18'), ('18', '13'), ('13', '12'), ('12', '11'), ('11', '16'), ('16', '17'), ('17', '16'), ('16', '11'), ('11', '6'), ('6', '1'), ('1', '2')]
# close
# Succesful:  100.0 %
# Test_times 89
# Current path: [7, 8, 3, 2, 3, 4, 9, 4, 3, 8, 13, 18, 23, 24, 19, 14, 19, 24, 23, 22, 17, 22, 21, 16, 21, 20, 15, 20, 21, 16, 11, 10, 5, 10, 11, 6, 1, 0, 1, 2, 7, 6, 7, 12, 13, 12, 11, 16, 17, 12, 7]
# Result is  1
# Episode distance: 500.0
# Episode length: 23
# Episode reward: 420.0
# path [('7', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '4'), ('4', '3'), ('3', '8'), ('8', '13'), ('13', '18'), ('18', '23'), ('23', '24'), ('24', '19'), ('19', '14'), ('14', '19'), ('19', '24'), ('24', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '20'), ('20', '21'), ('21', '16'), ('16', '11'), ('11', '10'), ('10', '5'), ('5', '10'), ('10', '11'), ('11', '6'), ('6', '1'), ('1', '0'), ('0', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '7'), ('7', '12'), ('12', '13'), ('13', '12'), ('12', '11'), ('11', '16'), ('16', '17'), ('17', '12'), ('12', '7')]
# close
# Succesful:  100.0 %
# Test_times 90
# Current path: [0, 1, 2, 7, 8, 9, 4, 3, 4, 9, 8, 13, 14, 19, 18, 19, 24, 23, 22, 23, 24, 19, 14, 13, 12, 17, 16, 21, 20, 15, 16, 17, 12, 7, 6, 5, 10, 5, 0, 1, 6, 11, 12, 13, 18, 13, 8, 7, 2, 1, 0]
# Result is  1
# Episode distance: 500.0
# Episode length: 17
# Episode reward: 400.0
# path [('0', '1'), ('1', '2'), ('2', '7'), ('7', '8'), ('8', '9'), ('9', '4'), ('4', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '22'), ('22', '23'), ('23', '24'), ('24', '19'), ('19', '14'), ('14', '13'), ('13', '12'), ('12', '17'), ('17', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '17'), ('17', '12'), ('12', '7'), ('7', '6'), ('6', '5'), ('5', '10'), ('10', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '11'), ('11', '12'), ('12', '13'), ('13', '18'), ('18', '13'), ('13', '8'), ('8', '7'), ('7', '2'), ('2', '1'), ('1', '0')]
# close
# Succesful:  100.0 %
# Test_times 91
# Current path: [24, 19, 14, 13, 8, 3, 2, 3, 8, 9, 4, 9, 8, 13, 18, 23, 22, 17, 22, 21, 16, 21, 20, 15, 10, 11, 6, 5, 0, 1, 6, 7, 2, 7, 8, 13, 12, 11, 12, 13, 18, 17, 16, 17, 18, 13, 14, 19, 24]
# Result is  1
# Episode distance: 480.0
# Episode length: 22
# Episode reward: 420.0
# path [('24', '19'), ('19', '14'), ('14', '13'), ('13', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '8'), ('8', '9'), ('9', '4'), ('4', '9'), ('9', '8'), ('8', '13'), ('13', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '10'), ('10', '11'), ('11', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '7'), ('7', '2'), ('2', '7'), ('7', '8'), ('8', '13'), ('13', '12'), ('12', '11'), ('11', '12'), ('12', '13'), ('13', '18'), ('18', '17'), ('17', '16'), ('16', '17'), ('17', '18'), ('18', '13'), ('13', '14'), ('14', '19'), ('19', '24')]
# close
# Succesful:  100.0 %
# Test_times 92
# Current path: [17, 18, 13, 8, 3, 2, 3, 4, 3, 8, 9, 14, 13, 14, 19, 18, 19, 24, 19, 18, 23, 22, 17, 22, 21, 20, 15, 10, 11, 10, 5, 6, 5, 0, 1, 6, 1, 2, 7, 12, 13, 18, 17, 16, 11, 6, 11, 16, 17]
# Result is  1
# Episode distance: 480.0
# Episode length: 28
# Episode reward: 460.0
# path [('17', '18'), ('18', '13'), ('13', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '3'), ('3', '8'), ('8', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '19'), ('19', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '20'), ('20', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '12'), ('12', '13'), ('13', '18'), ('18', '17'), ('17', '16'), ('16', '11'), ('11', '6'), ('6', '11'), ('11', '16'), ('16', '17')]
# close
# Succesful:  100.0 %
# Test_times 93
# Current path: [3, 8, 3, 2, 3, 4, 9, 4, 3, 8, 13, 14, 19, 18, 19, 24, 19, 18, 23, 22, 21, 16, 21, 20, 15, 16, 15, 10, 11, 6, 7, 2, 1, 0, 5, 0, 1, 2, 7, 6, 11, 12, 13, 18, 17, 16, 17, 12, 13, 8, 3]
# Result is  1
# Episode distance: 500.0
# Episode length: 24
# Episode reward: 400.0
# path [('3', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '4'), ('4', '3'), ('3', '8'), ('8', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '19'), ('19', '18'), ('18', '23'), ('23', '22'), ('22', '21'), ('21', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '15'), ('15', '10'), ('10', '11'), ('11', '6'), ('6', '7'), ('7', '2'), ('2', '1'), ('1', '0'), ('0', '5'), ('5', '0'), ('0', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '11'), ('11', '12'), ('12', '13'), ('13', '18'), ('18', '17'), ('17', '16'), ('16', '17'), ('17', '12'), ('12', '13'), ('13', '8'), ('8', '3')]
# close
# Succesful:  100.0 %
# Test_times 94
# Current path: [14, 9, 8, 3, 2, 3, 4, 3, 8, 9, 14, 19, 18, 19, 24, 23, 18, 13, 12, 11, 16, 21, 22, 21, 20, 21, 16, 15, 10, 5, 6, 5, 0, 5, 6, 1, 2, 7, 6, 7, 8, 13, 12, 7, 6, 11, 12, 17, 18, 19, 14]
# Result is  1
# Episode distance: 500.0
# Episode length: 26
# Episode reward: 440.0
# path [('14', '9'), ('9', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '3'), ('3', '8'), ('8', '9'), ('9', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '13'), ('13', '12'), ('12', '11'), ('11', '16'), ('16', '21'), ('21', '22'), ('22', '21'), ('21', '20'), ('20', '21'), ('21', '16'), ('16', '15'), ('15', '10'), ('10', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '7'), ('7', '8'), ('8', '13'), ('13', '12'), ('12', '7'), ('7', '6'), ('6', '11'), ('11', '12'), ('12', '17'), ('17', '18'), ('18', '19'), ('19', '14')]
# close
# Succesful:  100.0 %
# Test_times 95
# Current path: [11, 6, 7, 8, 3, 2, 3, 4, 9, 8, 9, 14, 13, 18, 19, 24, 23, 18, 23, 22, 17, 22, 21, 20, 21, 22, 17, 12, 11, 10, 15, 10, 11, 6, 5, 0, 5, 6, 1, 2, 7, 8, 13, 8, 7, 6, 11, 16, 11, 12, 17, 18, 17, 12, 11]
# Result is  1
# Episode distance: 540.0
# Episode length: 25
# Episode reward: 380.0
# path [('11', '6'), ('6', '7'), ('7', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '9'), ('9', '14'), ('14', '13'), ('13', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '20'), ('20', '21'), ('21', '22'), ('22', '17'), ('17', '12'), ('12', '11'), ('11', '10'), ('10', '15'), ('15', '10'), ('10', '11'), ('11', '6'), ('6', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '8'), ('8', '13'), ('13', '8'), ('8', '7'), ('7', '6'), ('6', '11'), ('11', '16'), ('16', '11'), ('11', '12'), ('12', '17'), ('17', '18'), ('18', '17'), ('17', '12'), ('12', '11')]
# close
# Succesful:  100.0 %
# Test_times 96
# Current path: [12, 7, 2, 3, 4, 9, 8, 9, 14, 13, 14, 19, 18, 19, 24, 23, 18, 17, 22, 17, 12, 11, 16, 15, 20, 21, 20, 15, 16, 11, 12, 7, 6, 5, 10, 5, 0, 1, 6, 1, 2, 7, 8, 13, 12]
# Result is  1
# Episode distance: 440.0
# Episode length: 20
# Episode reward: 480.0
# path [('12', '7'), ('7', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '17'), ('17', '22'), ('22', '17'), ('17', '12'), ('12', '11'), ('11', '16'), ('16', '15'), ('15', '20'), ('20', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '11'), ('11', '12'), ('12', '7'), ('7', '6'), ('6', '5'), ('5', '10'), ('10', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '8'), ('8', '13'), ('13', '12')]
# close
# Succesful:  100.0 %
# Test_times 97
# Current path: [13, 8, 3, 2, 3, 4, 9, 4, 3, 8, 13, 14, 19, 18, 23, 24, 23, 18, 17, 22, 21, 16, 15, 20, 15, 10, 11, 10, 5, 6, 5, 0, 5, 6, 1, 2, 7, 6, 11, 12, 13, 18, 17, 16, 11, 12, 17, 12, 13]
# Result is  1
# Episode distance: 480.0
# Episode length: 28
# Episode reward: 460.0
# path [('13', '8'), ('8', '3'), ('3', '2'), ('2', '3'), ('3', '4'), ('4', '9'), ('9', '4'), ('4', '3'), ('3', '8'), ('8', '13'), ('13', '14'), ('14', '19'), ('19', '18'), ('18', '23'), ('23', '24'), ('24', '23'), ('23', '18'), ('18', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '15'), ('15', '20'), ('20', '15'), ('15', '10'), ('10', '11'), ('11', '10'), ('10', '5'), ('5', '6'), ('6', '5'), ('5', '0'), ('0', '5'), ('5', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '11'), ('11', '12'), ('12', '13'), ('13', '18'), ('18', '17'), ('17', '16'), ('16', '11'), ('11', '12'), ('12', '17'), ('17', '12'), ('12', '13')]
# close
# Succesful:  100.0 %
# Test_times 98
# Current path: [11, 12, 17, 18, 13, 14, 9, 8, 3, 4, 3, 8, 9, 14, 19, 24, 23, 18, 23, 22, 17, 22, 21, 16, 15, 20, 15, 16, 11, 10, 5, 0, 1, 6, 1, 2, 7, 6, 7, 12, 17, 16, 11, 6, 11]
# Result is  1
# Episode distance: 440.0
# Episode length: 23
# Episode reward: 480.0
# path [('11', '12'), ('12', '17'), ('17', '18'), ('18', '13'), ('13', '14'), ('14', '9'), ('9', '8'), ('8', '3'), ('3', '4'), ('4', '3'), ('3', '8'), ('8', '9'), ('9', '14'), ('14', '19'), ('19', '24'), ('24', '23'), ('23', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '22'), ('22', '21'), ('21', '16'), ('16', '15'), ('15', '20'), ('20', '15'), ('15', '16'), ('16', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '1'), ('1', '6'), ('6', '1'), ('1', '2'), ('2', '7'), ('7', '6'), ('6', '7'), ('7', '12'), ('12', '17'), ('17', '16'), ('16', '11'), ('11', '6'), ('6', '11')]
# close
# Succesful:  100.0 %
# Test_times 99
# Current path: [20, 15, 10, 11, 12, 7, 8, 3, 4, 9, 8, 9, 14, 13, 14, 19, 24, 19, 14, 13, 18, 23, 22, 17, 16, 21, 20, 15, 16, 11, 10, 5, 0, 5, 10, 11, 6, 11, 12, 7, 2, 1, 2, 7, 8, 13, 12, 17, 18, 17, 16, 15, 20]
# Result is  1
# Episode distance: 520.0
# Episode length: 23
# Episode reward: 420.0
# path [('20', '15'), ('15', '10'), ('10', '11'), ('11', '12'), ('12', '7'), ('7', '8'), ('8', '3'), ('3', '4'), ('4', '9'), ('9', '8'), ('8', '9'), ('9', '14'), ('14', '13'), ('13', '14'), ('14', '19'), ('19', '24'), ('24', '19'), ('19', '14'), ('14', '13'), ('13', '18'), ('18', '23'), ('23', '22'), ('22', '17'), ('17', '16'), ('16', '21'), ('21', '20'), ('20', '15'), ('15', '16'), ('16', '11'), ('11', '10'), ('10', '5'), ('5', '0'), ('0', '5'), ('5', '10'), ('10', '11'), ('11', '6'), ('6', '11'), ('11', '12'), ('12', '7'), ('7', '2'), ('2', '1'), ('1', '2'), ('2', '7'), ('7', '8'), ('8', '13'), ('13', '12'), ('12', '17'), ('17', '18'), ('18', '17'), ('17', '16'), ('16', '15'), ('15', '20')]
# close
# Succesful:  100.0 %
# Average Reward: 415.6
# Average Length: 23.64
# Average Distance: 503.6
# Succesful:  100.0 %
